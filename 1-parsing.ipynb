# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.model_selection import train_test_split

# %%
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/TFTP.csv') #5odi goz2 so3'ir awi 3shan da 9GB --mrdash y load asln 7ta b new run
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_UDP.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_SSDP.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_SNMP.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_NetBIOS.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_MSSQL.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_DNS.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_LDAP.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/DrDoS_NTP.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/Syn.csv')
#df=pd.read_csv('/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/01-12/UDPLag.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (85) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.sort_values(by=[' Label'])

# %%
df[' Label'].value_counts()

# %%
data = df.head(2100)

# %%
data
# Out:
#          Unnamed: 0                                  Flow ID  ...  Inbound   Label
# 1752551       18813      192.168.50.8-72.21.91.29-59728-80-6  ...        0  BENIGN
# 2287674       46400   172.217.10.99-192.168.50.7-443-52111-6  ...        1  BENIGN
# 2287673          17   172.217.10.99-192.168.50.7-443-52111-6  ...        1  BENIGN
# 1369081        8140     172.217.7.1-192.168.50.6-443-57780-6  ...        1  BENIGN
# 2287671      119335  172.217.12.194-192.168.50.7-443-52107-6  ...        1  BENIGN
# ...             ...                                      ...  ...      ...     ...
# 1323861       86994         192.168.50.6-4.2.2.4-60413-53-17  ...        0  BENIGN
# 2289982       52484    192.168.50.6-208.185.55.51-57798-80-6  ...        0  BENIGN
# 1336950        8305     172.217.7.1-192.168.50.6-443-57780-6  ...        0  BENIGN
# 2289985          24     184.86.74.35-192.168.50.6-80-57796-6  ...        1  BENIGN
# ...

# %%
data = data.append(df.iloc[-100000:])

# %%
data.shape
# Out:
# (102100, 88)

# %%
#data.to_csv('Subset.csv')

# %%
data.to_csv('Subset.csv', mode='a', header=False)

# %%
# !cp Subset.csv "/content/gdrive/MyDrive/DEBI/Masters/Ai for cs/Data Shrinked"
